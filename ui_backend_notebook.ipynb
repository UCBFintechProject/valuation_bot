# %%
import pandas as pd
from pathlib import Path

# %%
data = Path("data/FS_sp500_merged_cleaned_stats.csv")
df = pd.read_csv(data, delimiter=",").rename(columns={"Unnamed: 0":"Ticker"})
df = df.set_index("Ticker")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, A to ZBRA
# Data columns (total 68 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   RecentPrice                            152 non-null    float64
#  1   Beta                                   152 non-null    float64
#  2   AnnualDividendRate                     152 non-null    float64
#  3   ROE(%)                                 152 non-null    float64
#  4   ROA(%)                                 152 non-null    float64
#  5   ProfitMargin(%)                        152 non-null    float64
#  6   TotalCash                              152 non-null    float64
#  7   TotalDebt                              152 non-null    float64
#  8   OutstandingShares                      152 non-null    float64
#  9   intangibleAssets                       152 non-null    float64
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="p@ssw0rd"
)

print(mydb)

# %%
#Databas already exists
mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE FS_sp500_merged_cleaned_stats_database")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="p@ssw0rd",
  database="FS_sp500_merged_cleaned_stats_database"
)

# %%
# import mysql.connector as msql
# from mysql.connector import Error
# try:
#     conn = mysql.connect(host='localhost', database='FS_sp500_merged_cleaned_stats_database', user='root', password='p@ssw0rd')
#     if conn.is_connected():
#         cursor = conn.cursor()
#         cursor.execute("select database();")
#         record = cursor.fetchone()
#         print("You're connected to database: ", record)
#         cursor.execute('DROP TABLE IF EXISTS table_data;')
#         print('Creating table....')
# # in the below line please pass the create table statement which you want #to create
#         cursor.execute("CREATE TABLE employee_data(first_name varchar(255),last_name varchar(255),company_name varchar(255),address varchar(255),city varchar(255),county varchar(255),state varchar(255),zip int,phone1 varchar(255),phone2 varchar(255),email varchar(255),web varchar(255))")
#         print("Table is created....")
#         #loop through the data frame
#         for i,row in empdata.iterrows():
#             #here %S means string values 
#             sql = "INSERT INTO employee.employee_data VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
#             cursor.execute(sql, tuple(row))
#             print("Record inserted")
#             # the connection is not auto committed by default, so we must commit to save our changes
#             conn.commit()
# except Error as e:
#             print("Error while connecting to MySQL", e)

# %%
CREATE TABLE table(
    `Ticker` string(11) NOT NULL,
    `RecentPrice` float(152) NOT NULL,
    `Beta` float(152) NOT NULL,
    `AnnualDividendRate` float(152) NOT NULL,
    `ROE(%)` float(152) NOT NULL,
    `ROA(%)` float(152) NOT NULL,
    `ProfitMargin(%)` float(152) NOT NULL,
    `TotalCash` float(152) NOT NULL,
    `TotalDebt` float(152) NOT NULL,
    `OutstandingShares` float(152) NOT NULL,
    `intangibleAssets` float(152) NOT NULL,
    `capitalSurplus` float(152) NOT NULL,
    `totalLiab` float(152) NOT NULL,
    `totalStockholderEquity` float(152) NOT NULL,
    `otherCurrentLiab` float(152) NOT NULL,
    `totalAssets` float(152) NOT NULL,
    `commonStock` float(152) NOT NULL,
    `otherCurrentAssets` float(152) NOT NULL,
    `retainedEarnings` float(152) NOT NULL,
    `otherLiab` float(152) NOT NULL,
    `goodWill` float(152) NOT NULL,
    `treasuryStock` float(152) NOT NULL,
    `otherAssets` float(152) NOT NULL,
    `cash` float(152) NOT NULL,
    `totalCurrentLiabilities` float(152) NOT NULL,
    `otherStockholderEquity` float(152) NOT NULL,
    `propertyPlantEquipment` float(152) NOT NULL,
    `totalCurrentAssets` float(152) NOT NULL,
    `longTermInvestments` float(152) NOT NULL,
    `netTangibleAssets` float(152) NOT NULL,
    `netReceivables` float(152) NOT NULL,
    `longTermDebt` float(152) NOT NULL,
    `inventory` float(152) NOT NULL,
    `accountsPayable` float(152) NOT NULL,
    `shortLongTermDebt` float(152) NOT NULL,
    `incomeBeforeTax` float(152) NOT NULL,
    `netIncome` float(152) NOT NULL,
    `sellingGeneralAdministrative` float(152) NOT NULL,
    `grossProfit` float(152) NOT NULL,
    `ebit` float(152) NOT NULL,
    `operatingIncome` float(152) NOT NULL,
    `interestExpense` float(152) NOT NULL,
    `incomeTaxExpense` float(152) NOT NULL,
    `totalRevenue` float(152) NOT NULL,
    `totalOperatingExpenses` float(152) NOT NULL,
    `costOfRevenue` float(152) NOT NULL,
    `totalOtherIncomeExpenseNet` float(152) NOT NULL,
    `netIncomeFromContinuingOps` float(152) NOT NULL,
    `netIncomeApplicableToCommonShares` float(152) NOT NULL,
    `investments` float(152) NOT NULL,
    `changeToLiabilities` float(152) NOT NULL,
    `totalCashflowsFromInvestingActivities` float(152) NOT NULL,
    `totalCashFromFinancingActivities` float(152) NOT NULL,
    `changeToOperatingActivities` float(152) NOT NULL,
    `issuanceOfStock` float(152) NOT NULL,
    `netIncome.1` float(152) NOT NULL,
    `changeInCash` float(152) NOT NULL,
    `repurchaseOfStock` float(152) NOT NULL,
    `effectOfExchangeRate` float(152) NOT NULL,
    `totalCashFromOperatingActivities` float(152) NOT NULL,
    `depreciation` float(152) NOT NULL,
    `otherCashflowsFromInvestingActivities` float(152) NOT NULL,
    `dividendsPaid` float(152) NOT NULL,
    `changeToAccountReceivables` float(152) NOT NULL,
    `changeToNetincome` float(152) NOT NULL,
    `capitalExpenditures` float(152) NOT NULL,
    `netBorrowings` float(152) NOT NULL,
    `otherCashflowsFromFinancingActivities` float(152) NOT NULL,
    `MarketCap` float(152) NOT NULL,
    );
# Out:
#   File "/var/folders/gp/04k4d_s94g9f05fm7_2n4z140000gn/T/ipykernel_17364/154200734.py", line 1
#     CREATE TABLE table(
#                ^
# SyntaxError: invalid syntax
