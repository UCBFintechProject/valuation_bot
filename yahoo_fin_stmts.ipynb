# %%
pip install git+https://github.com/luckfu/yahoo_financials_stmt.git
# Out:
# ...
#   Cloning https://github.com/luckfu/yahoo_financials_stmt.git to /private/var/folders/4b/vznp33fn2qq_x93m7sr629_h0000gn/T/pip-req-build-2hhbuwps
#   Running command git clone -q https://github.com/luckfu/yahoo_financials_stmt.git /private/var/folders/4b/vznp33fn2qq_x93m7sr629_h0000gn/T/pip-req-build-2hhbuwps
#   Resolved https://github.com/luckfu/yahoo_financials_stmt.git to commit 20652a4e5200e080dbbfdfe01c65aa0e704e6260
# ...
#   Created wheel for yahoo-financials-stmt: filename=yahoo_financials_stmt-0.0.1-py3-none-any.whl size=6053 sha256=62084b078befadecd20658c19bca1e8b50e79287ba78768db787160b9088ea4e
#   Stored in directory: /private/var/folders/4b/vznp33fn2qq_x93m7sr629_h0000gn/T/pip-ephem-wheel-cache-_vui3d0j/wheels/37/70/aa/f475efd440c28e3e64395cc61253aa66830add217210eb723b
# Successfully built yahoo-financials-stmt
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import datetime
from yahoo_financials_stmt import YahooFinancialsStmt
yfs = YahooFinancialsStmt()
finances=yfs.get_financials('box')
yfs.earnings_between()
finances
# Out:
# https://finance.yahoo.com/quote/box/financials?p=box
# {'balance_annual':             intangibleAssets  capitalSurplus   totalLiab  \
#  endDate
#  2022-01-31          37118000       972020000  1299216000
#  2021-01-31          24820000      1473666000  1200617000
#  2020-01-31          25115000      1302072000   937634000
#  2019-01-31           3514000      1166443000   618756000
#
#              totalStockholderEquity  deferredLongTermLiab  otherCurrentLiab  \
#  endDate
#  2022-01-31              -395087000              72884000         519485000
#  2021-01-31               151065000              66481000         443929000
#  2020-01-31                22357000              62762000         407493000
#  2019-01-31                31405000              53880000         353590000
#
#              totalAssets  commonStock  otherCurrentAssets  retainedEarnings  \
#  endDate
#  2022-01-31   1392009000        15000            46639000       -1362579000
# ...

# %%
AAPL: 2022 Q1 ({Dataset})    2021 Q4.  2021 Q3 ...... 40



Dataset = 
['Ticker', 'RecentPrice', 'Beta', 'AnnualDividendRate', 'ROE(%)', 'ROA(%)',
       'ProfitMargin(%)', 'TotalCash', 'TotalDebt', 'OutstandingShares',
       'intangibleAssets', 'capitalSurplus', 'totalLiab',
       'totalStockholderEquity', 'otherCurrentLiab', 'totalAssets',
       'commonStock', 'otherCurrentAssets', 'retainedEarnings', 'otherLiab',
       'goodWill', 'treasuryStock', 'otherAssets', 'cash',
       'totalCurrentLiabilities', 'otherStockholderEquity',
       'propertyPlantEquipment', 'totalCurrentAssets', 'longTermInvestments',
       'netTangibleAssets', 'netReceivables', 'longTermDebt', 'inventory',
       'accountsPayable', 'shortLongTermDebt', 'incomeBeforeTax', 'netIncome',
       'sellingGeneralAdministrative', 'grossProfit', 'ebit',
       'operatingIncome', 'interestExpense', 'incomeTaxExpense',
       'totalRevenue', 'totalOperatingExpenses', 'costOfRevenue',
       'totalOtherIncomeExpenseNet', 'netIncomeFromContinuingOps',
       'netIncomeApplicableToCommonShares', 'investments',
       'changeToLiabilities', 'totalCashflowsFromInvestingActivities',
       'totalCashFromFinancingActivities', 'changeToOperatingActivities',
       'issuanceOfStock', 'netIncome', 'changeInCash', 'repurchaseOfStock',
       'effectOfExchangeRate', 'totalCashFromOperatingActivities',
       'depreciation', 'otherCashflowsFromInvestingActivities',
       'dividendsPaid', 'changeToAccountReceivables', 'changeToNetincome',
       'capitalExpenditures', 'netBorrowings',
       'otherCashflowsFromFinancingActivities', 'MarketCap']



Valuation_score = Recent Price / Model Output (Val Score) = between -1 and 1

Ts:
    
    Q1-Year |. Stock Price.  | Val Score

Problem Statement:  We're using 10 years Price data, and predicting Market Cap based on 
                    Recent Financial Statement.
