# %%
#PLease pip install yfinance before running

import time
import datetime
import pandas as pd
import yfinance as yf
from yahoo_fin.stock_info import get_data
import yahoo_fin.stock_info as si
# from yahoo_financials_stmt

# %%
Stock_Symbol = "AAPL"

# %%
SP500_Stock_list = get_data(Stock_Symbol, start_date="1/12/2012", end_date="1/12/2022", index_as_date = True, interval="1mo")
SP500_Stock_list = SP500_Stock_list.drop(columns = ['open','high','low','adjclose','volume'])
SP500_Stock_list
# Out:
#                  close ticker
# 2012-02-01   19.372856   AAPL
# 2012-03-01   21.412500   AAPL
# 2012-04-01   20.856428   AAPL
# 2012-05-01   20.633215   AAPL
# 2012-06-01   20.857143   AAPL
# ...                ...    ...
# 2021-09-01  141.500000   AAPL
# 2021-10-01  149.800003   AAPL
# 2021-11-01  165.300003   AAPL
# 2021-12-01  177.570007   AAPL
# 2022-01-01  174.779999   AAPL
#
# [120 rows x 2 columns]

# %%
sp500_stocks_list = si.tickers_sp500()

print("sp500_stocks_list:", len(sp500_stocks_list))
sp500_stocks_list[0:10]
# Out:
# sp500_stocks_list: 503
# ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN', 'ADBE']

# %%
sp = pd.DataFrame(sp500_stocks_list)
sp
# Out:
#         0
# 0       A
# 1     AAL
# 2     AAP
# 3    AAPL
# 4    ABBV
# ..    ...
# 498   YUM
# 499   ZBH
# 500  ZBRA
# 501  ZION
# 502   ZTS
#
# [503 rows x 1 columns]

# %%
si.get_stats_valuation(Stock_Symbol)
# Out:
#                   Unnamed: 0 As of Date: 7/11/2022Current 3/31/2022  \
# 0      Market Cap (intraday)                      191.31B   207.24B
# 1           Enterprise Value                      200.24B   216.00B
# 2               Trailing P/E                        25.35     30.04
# 3                Forward P/E                        22.62     24.63
# 4  PEG Ratio (5 yr expected)                         6.64      8.15
# 5          Price/Sales (ttm)                         4.38      4.92
# 6           Price/Book (mrq)                         5.40      5.79
# 7   Enterprise Value/Revenue                         4.50     18.16
# 8    Enterprise Value/EBITDA                        15.40     56.40
#
#   12/31/2021 9/30/2021 6/30/2021
# 0    248.28B   208.89B   205.52B
# 1    256.98B   218.44B   215.59B
# 2      34.92     33.28     36.34
# 3      29.67     25.13     26.74
# 4       2.75      2.74      2.94
# 5       5.96      5.26      5.55
# 6       7.21      6.18      6.12
# ...

# %%
Valuation_data = pd.DataFrame(si.get_stats_valuation(Stock_Symbol))
Valuation_data.T
# Out:
#                                                   0                 1  \
# Unnamed: 0                    Market Cap (intraday)  Enterprise Value
# As of Date: 7/11/2022Current                191.31B           200.24B
# 3/31/2022                                   207.24B           216.00B
# 12/31/2021                                  248.28B           256.98B
# 9/30/2021                                   208.89B           218.44B
# 6/30/2021                                   205.52B           215.59B
#
#                                          2            3  \
# Unnamed: 0                    Trailing P/E  Forward P/E
# As of Date: 7/11/2022Current         25.35        22.62
# 3/31/2022                            30.04        24.63
# 12/31/2021                           34.92        29.67
# 9/30/2021                            33.28        25.13
# 6/30/2021                            36.34        26.74
#
#                                                       4                  5  \
# ...

# %%
balance_sheet = si.get_balance_sheet(Stock_Symbol)
balance_sheet
# Out:
# endDate                        2021-12-31   2020-12-31   2019-12-31  \
# Breakdown
# intangibleAssets              12739000000  14784000000  17025000000
# totalLiab                     39172000000  39545000000  36586000000
# totalStockholderEquity        35802000000  32784000000  31088000000
# minorityInterest                222000000    219000000    213000000
# otherCurrentLiab               1234000000   1658000000    950000000
# totalAssets                   75196000000  72548000000  67887000000
# commonStock                   24470000000  24145000000  23853000000
# otherCurrentAssets              292000000     90000000    148000000
# retainedEarnings              31528000000  27627000000  25847000000
# otherLiab                      7815000000   8209000000   8307000000
# goodWill                      23231000000  23744000000  23195000000
# treasuryStock                -20196000000 -18988000000 -18612000000
# otherAssets                    4363000000   2784000000   2443000000
# ...

# %%
Balance_sheet_data = pd.DataFrame(si.get_balance_sheet(Stock_Symbol))
Balance_sheet_data.T
# Out:
# Breakdown   intangibleAssets    totalLiab  totalStockholderEquity  \
# endDate
# 2021-12-31       12739000000  39172000000             35802000000
# 2020-12-31       14784000000  39545000000             32784000000
# 2019-12-31       17025000000  36586000000             31088000000
# 2018-12-31       18942000000  36451000000             30524000000
#
# Breakdown   minorityInterest  otherCurrentLiab  totalAssets  commonStock  \
# endDate
# 2021-12-31         222000000        1234000000  75196000000  24470000000
# 2020-12-31         219000000        1658000000  72548000000  24145000000
# 2019-12-31         213000000         950000000  67887000000  23853000000
# 2018-12-31         198000000         868000000  67173000000  23512000000
#
# Breakdown   otherCurrentAssets  retainedEarnings   otherLiab  ...  \
# endDate                                                       ...
# 2021-12-31           292000000       31528000000  7815000000  ...
# ...

# %%
cash_flow_statement = si.get_cash_flow(Stock_Symbol,"01/16/2022")
cash_flow_statement
# Out:
# endDate                                  2021-12-31    2020-12-31  \
# Breakdown
# investments                           -9.600000e+07 -7.300000e+07
# changeToLiabilities                    1.288000e+09  1.766000e+09
# totalCashflowsFromInvestingActivities -2.008000e+09 -2.215000e+09
# netBorrowings                         -2.480000e+08 -5.000000e+07
# totalCashFromFinancingActivities      -5.494000e+09 -2.779000e+09
# changeToOperatingActivities           -3.120000e+08 -6.270000e+08
# issuanceOfStock                        2.550000e+08  2.450000e+08
# netIncome                              7.071000e+09  4.495000e+09
# changeInCash                           2.961000e+09  2.978000e+09
# repurchaseOfStock                     -2.299000e+09 -4.030000e+08
# effectOfExchangeRate                  -7.000000e+07  7.100000e+07
# totalCashFromOperatingActivities       1.053300e+10  7.901000e+09
# depreciation                           3.538000e+09  3.327000e+09
# ...

# %%
Balance_sheet_data = pd.DataFrame(si.get_cash_flow(Stock_Symbol,"01/16/2022"))
Balance_sheet_data.T
# Out:
# Breakdown   investments  changeToLiabilities  \
# endDate
# 2021-12-31  -96000000.0         1.288000e+09
# 2020-12-31  -73000000.0         1.766000e+09
# 2019-12-31  -82000000.0         2.200000e+08
# 2018-12-31  -58000000.0         7.470000e+08
#
# Breakdown   totalCashflowsFromInvestingActivities  netBorrowings  \
# endDate
# 2021-12-31                          -2.008000e+09  -2.480000e+08
# 2020-12-31                          -2.215000e+09  -5.000000e+07
# 2019-12-31                          -1.815000e+09  -1.599000e+09
# 2018-12-31                          -1.356000e+09  -8.450000e+09
#
# Breakdown   totalCashFromFinancingActivities  changeToOperatingActivities  \
# endDate
# 2021-12-31                     -5.494000e+09                 -312000000.0
# 2020-12-31                     -2.779000e+09                 -627000000.0
# 2019-12-31                     -4.289000e+09                 -138000000.0
# 2018-12-31                     -1.039100e+10                   23000000.0
#
# ...
